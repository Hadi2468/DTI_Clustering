# %% [markdown]
# ## Import some helpful libraries

# %%
## Import some helpful libraries
print("    Version control\n------------------------")
import os, fnmatch, random, math, sys, datetime
from pathlib import Path
import numpy as np;              print("Numpy\t\t", np.__version__)
import matplotlib as mpl;        print("matplotlib\t", mpl.__version__)
import matplotlib.pyplot as plt
import pandas as pd;             print("Pandas\t\t {}".format(pd.__version__))
from IPython.display import Image

# import nibabel as nib;           print("NiBabel\t\t {}".format(nib.__version__))
# from nibabel.testing import data_path
# import imageio;                  print("imageio\t\t {}".format(imageio.__version__))
# import h5py;                     print("H5py\t\t {}".format(h5py.__version__))
# import sklearn;                  print("Scikit-learn\t {}".format(sklearn.__version__))
# from sklearn.cluster import KMeans
# from sklearn.decomposition import PCA
# from scipy.cluster import hierarchy
# from scipy.cluster.hierarchy import dendrogram, linkage
# import skimage;                  print("Scikit-image\t {}".format(skimage.__version__))
# import tensorflow as tf;         print("TensorFlow\t {}".format(tf.__version__))
# import keras;                    print("Keras\t\t {}".format(keras.__version__))
# import tensorflow.keras.backend as K
# from tensorflow.keras import models, Input, Model
# from tensorflow.keras.layers import Dense, Flatten, Reshape, BatchNormalization, Conv3D, MaxPooling3D, UpSampling3D, ZeroPadding3D
# from tensorflow.keras.activations import relu, sigmoid
# from tensorflow.keras.losses import SparseCategoricalCrossentropy
# from tensorflow.keras.initializers import *
# from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
# from keras.engine.topology import Layer, InputSpec
# from keras.optimizers import SGD
# from tensorflow.keras.utils import plot_model
# %load_ext tensorboard       
# %reload_ext tensorboard
# Out:
#     Version control
# ------------------------
# Numpy		 1.19.4
# matplotlib	 3.3.3
# Pandas		 1.1.4

# %% [markdown]
# ## Loading Data

# %%
## Loading LF and joining (Cluster -*- NeuroCognitive) scores

df_cluster_join_base_GIA        = pd.read_csv(r'../Data/data_random_1/Neurocognitive_Joins/cluster_base_GIA.csv')
df_cluster_join_base_ProcSpd    = pd.read_csv(r'../Data/data_random_1/Neurocognitive_Joins/cluster_base_Proc_Spd.csv')
df_cluster_join_base_WorkingMem = pd.read_csv(r'../Data/data_random_1/Neurocognitive_Joins/cluster_base_Working_Mem.csv')
df_cluster_join_base_BroadAttn  = pd.read_csv(r'../Data/data_random_1/Neurocognitive_Joins/cluster_base_Broad_Attn.csv')

df_cluster_join_m36base_GIA        = pd.read_csv(r'../Data/data_random_1/Neurocognitive_Joins/cluster_m36base_GIA.csv')
df_cluster_join_m36base_ProcSpd    = pd.read_csv(r'../Data/data_random_1/Neurocognitive_Joins/cluster_m36base_Proc_Spd.csv')
df_cluster_join_m36base_WorkingMem = pd.read_csv(r'../Data/data_random_1/Neurocognitive_Joins/cluster_m36base_Working_Mem.csv')
df_cluster_join_m36base_BroadAttn  = pd.read_csv(r'../Data/data_random_1/Neurocognitive_Joins/cluster_m36base_Broad_Attn.csv')

LF_500 = pd.read_csv('../Data/data_random_1/LF/LF_500_py.csv')
LF_1500 = pd.read_csv('../Data/data_random_1/LF/LF_1500_py.csv')
LF_1500
# Out:
#             ID  class_e1500         0         1         2         3        4  \
# 0    Pat_001_1            1 -0.124379  1.648069 -0.074343  0.110323  0.07609
# 1    Pat_002_1            2 -0.124379  1.648069 -0.074343  0.110323  0.07609
# 2    Pat_003_1            3 -0.328410  1.344942 -0.502659  0.365912  0.34062
# 3    Pat_004_1            0 -0.124379  1.648069 -0.074343  0.110323  0.07609
# 4    Pat_005_1            1 -0.124379  1.648069 -0.074343  0.110323  0.07609
# ..         ...          ...       ...       ...       ...       ...      ...
# 119  Pat_141_1            0 -0.124379  1.648069 -0.074343  0.110323  0.07609
# 120  Pat_142_1            0 -0.124379  1.648069 -0.074343  0.110323  0.07609
# 121  Pat_143_1            0 -0.124379  1.648069 -0.074343  0.110323  0.07609
# 122  Pat_144_1            0 -0.124379  1.648069 -0.074343  0.110323  0.07609
# 123  Pat_145_1            0 -0.124379  1.648069 -0.074343  0.110323  0.07609
#
# ...

# %% [markdown]
# ## Joining of LF_500 with Scores

# %%
## LF_500 for Base scores
df = pd.merge(df_cluster_join_base_GIA, LF_500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e1500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e500_base_GIA.csv')

df = pd.merge(df_cluster_join_base_ProcSpd, LF_500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e1500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e500_base_ProcSpd.csv')

df = pd.merge(df_cluster_join_base_WorkingMem, LF_500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e1500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e500_base_WorkingMem.csv')

df = pd.merge(df_cluster_join_base_BroadAttn, LF_500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e1500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e500_base_BroadAttn.csv')

##---------------------------------------------------------------------------------
## LF_500 for (Month36-Base) scores
df = pd.merge(df_cluster_join_m36base_GIA, LF_500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e1500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e500_m36base_GIA.csv')

df = pd.merge(df_cluster_join_m36base_ProcSpd, LF_500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e1500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e500_m36base_ProcSpd.csv')

df = pd.merge(df_cluster_join_m36base_WorkingMem, LF_500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e1500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e500_m36base_WorkingMem.csv')

df = pd.merge(df_cluster_join_m36base_BroadAttn, LF_500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e1500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e500_m36base_BroadAttn.csv')

# %% [markdown]
# ## Joining of LF_1500 with Scores

# %%
## LF_1500 for Base scores
df = pd.merge(df_cluster_join_base_GIA, LF_1500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e1500_base_GIA.csv')

df = pd.merge(df_cluster_join_base_ProcSpd, LF_1500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e1500_base_ProcSpd.csv')

df = pd.merge(df_cluster_join_base_WorkingMem, LF_1500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e1500_base_WorkingMem.csv')

df = pd.merge(df_cluster_join_base_BroadAttn, LF_1500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e1500_base_BroadAttn.csv')

# ##---------------------------------------------------------------------------------
# ## LF_1500 for (Month36-Base) scores
df = pd.merge(df_cluster_join_m36base_GIA, LF_1500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e1500_m36base_GIA.csv')

df = pd.merge(df_cluster_join_m36base_ProcSpd, LF_1500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e1500_m36base_ProcSpd.csv')

df = pd.merge(df_cluster_join_m36base_WorkingMem, LF_1500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e1500_m36base_WorkingMem.csv')

df = pd.merge(df_cluster_join_m36base_BroadAttn, LF_1500, how='inner', on=['ID'])
df.index = df.ID
df = df.drop(['ID', 'class_e500'], axis=1)
# df.to_csv(r'../Data/data_random_1/LF_Joins/LF_e1500_m36base_BroadAttn.csv')
df
# Out:
#            class_e1500  Broad_Attn_SS         0         1         2         3  \
# ID
# Pat_001_1            1             22 -0.124379  1.648069 -0.074343  0.110323
# Pat_002_1            2              6 -0.124379  1.648069 -0.074343  0.110323
# Pat_004_1            0             -9 -0.124379  1.648069 -0.074343  0.110323
# Pat_007_1            2             16 -0.124379  1.648069 -0.074343  0.110323
# Pat_011_1            0             11 -0.124379  1.648069 -0.074343  0.110323
# Pat_013_1            0              7 -0.124379  1.648069 -0.074343  0.110323
# Pat_014_1            1             -7 -0.124379  1.648069 -0.074343  0.110323
# Pat_017_1            1              2 -0.124379  1.648069 -0.074343  0.110323
# Pat_021_1            1            -11 -0.124379  1.648069 -0.074343  0.110323
# Pat_023_1            0             23 -0.124379  1.648069 -0.074343  0.110323
# Pat_025_1            2             16 -0.124379  1.648069 -0.074343  0.110323
# ...
